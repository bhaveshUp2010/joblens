# %%
import requests

# %%
url = "https://remoteok.com/api"
res = requests.get(url)

data = res.json()
data.pop(0)
print(len(data))
# Out:
# 95

# %%
data[0]
# Out:
# {'slug': 'remote-lead-security-engineer-copia-automation-1130876',
#  'id': '1130876',
#  'epoch': 1774454404,
#  'date': '2026-03-25T16:00:04+00:00',
#  'company': 'Copia Automation',
#  'company_logo': '',
#  'position': 'Lead Security Engineer',
#  'tags': ['security',
#   'design',
#   'saas',
#   'support',
#   'developer',
#   'cloud',
#   'api',
#   'management',
#   'lead',
#   'senior',
#   'operations',
#   'operational',
#   'healthcare',
#   'engineer',
#   'engineering',
#   'linux',
#   'executive',
#   'digital nomad'],
# ...
